# %%
import pandas
import urllib
from selenium import webdriver
import numpy as np
from time import sleep
import requests
from bs4 import BeautifulSoup
import re

# %%
gpo=webdriver.Chrome()
gpo.get('https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC')

# %%
def extract_text(gpo):
    try:
        handles = list(gpo.window_handles)
        assert len(handles) > 1
        gpo.switch_to_window(handles[1])
        extracted_stuff = extract_text_from_url(gpo.current_url)

        ## create a file in local repository
        file_name = create_text_file_name(gpo.current_url)
        file = open(file_name,'w')
        file.write(extracted_stuff)
        file.close()
        print("try close")
        gpo.close()
        return file_name
    except:
        print("except close")
        gpo.close()

# %%
def extract_mods(gpo, txt_file_name):
    try:
        handles = list(gpo.window_handles)
        assert len(handles) > 1
        gpo.switch_to_window(handles[1])

        mods_url = gpo.current_url
        sleep(1)
        extracted_stuff = extract_mods_from_url(mods_url)

        ## create a file in local repository
        file_name = txt_file_name[0:-3] + 'xml'
        file = open(file_name, 'w')
        file.write(extracted_stuff)
        file.close()
        print("try close")
        gpo.close()
    except:
        print("except close")
        gpo.close()

# %%
def create_text_file_name(url):
    pattern = '(?<=html/).*'
    name = re.findall(pattern, url)
    return name[0][:-3] + 'txt'

# %%
def extract_mods_from_url(url):
    stuff = requests.get(url)
    stuff_parsed = BeautifulSoup(stuff.content, 'xml')
    return str(stuff_parsed.find_all('mods')[0])

# %%
def extract_text_from_url(url):
    stuff = requests.get(url)
    stuff_parsed = BeautifulSoup(stuff.content, "html")
    return stuff_parsed.get_text()

# %%
april = 3
DAY = 3
year = gpo.find_elements_by_xpath(".//div[@class='level1 browse-level']/a")
for i in np.arange(len(year)):
    if i == 0:
        continue
    if i == 2:
        break
    time_y = i
    year = gpo.find_elements_by_xpath(".//div[@class='level1 browse-level']/a")
    x = year[i].click()
    month = gpo.find_elements_by_xpath(".//div[@class='level2 browse-level']/a")
    for i in np.arange(len(month)):
        if april != 0:
            april -= 1
            continue
        time_m = i
        month = gpo.find_elements_by_xpath(".//div[@class='level2 browse-level']/a")
        month[i].click()
        day = gpo.find_elements_by_xpath(".//div[@class='level3 browse-level']/a")
        print(len(day))
        for i in np.arange(len(day)):
            print(i)
            if DAY != 0:
                DAY -= 1
                continue
            time_d = i
            day = gpo.find_elements_by_xpath(".//div[@class='level3 browse-level']/a")
            print(i)
            day[i].click()
            try: 
                print(i)
                house = gpo.find_element_by_partial_link_text('House')
                house.click()
                house_more = gpo.find_elements_by_partial_link_text('More')
                house_more = house_more[1:]
                print(len(house_more))
                print(house_more)
                for j in np.arange(len(house_more)):
                    position = 1
                    subposition = 1
                    try:
                        print("       ", j)
                        house_more = gpo.find_elements_by_partial_link_text('More')
                        subposition = 2
                        house_more = house_more[1:]
                        subposition = 3
                        
                        position = 2

                        house_more[j].click()
                        subposition = 2
                        house_text = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[1]/td[2]/a[1]')
                        subposition = 3
                        house_mods = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[2]/td[2]/a')
                        subposition = 4
                        default_handle = gpo.current_window_handle
                        subposition = 5
                        house_text.click()
                        subposition = 6
                        
                        position = 3

                        #changing default window & save file, return name
                        text_file_name = extract_text(gpo)
                        
                        position = 4

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 5

                        #go to mods page & save file
                        house_mods.click()
                        subposition = 2
                        extract_mods(gpo, text_file_name)
                        
                        position = 6

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 7
                        
                        gpo.back()
                        
                        position = 8
                        
                    except:
                        print("failed", j)
                        print(gpo.current_url)
                        print(position)
                        print(subposition)
                        gpo.back()
            except:
                print(j, "Did not find house")
                print(gpo.current_url)
            
            try:
                print(i)
                senate = gpo.find_element_by_partial_link_text('Senate')
                senate.click()
                senate_more = gpo.find_elements_by_partial_link_text('More')
                senate_more = senate_more[1:]
                print(len(senate_more))
                print(senate_more)
                for j in np.arange(len(senate_more)):
                    position = 1
                    subposition = 1
                    try:
                        senate_more = gpo.find_elements_by_partial_link_text('More')
                        subposition = 2
                        senate_more = senate_more[1:]
                        subposition = 3
                        
                        position = 2

                        senate_more[j].click()
                        subposition = 2
                        senate_text = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[1]/td[2]/a[1]')
                        subposition = 3
                        senate_mods = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[2]/td[2]/a')
                        subposition = 4
                        default_handle = gpo.current_window_handle
                        subposition = 5
                        senate_text.click()
                        subposition = 6
                        
                        position = 3

                        #changing default window & save file, return name
                        text_file_name = extract_text(gpo)
                        
                        position = 4

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 5

                        #go to mods page & save file
                        senate_mods.click()
                        subposition = 2
                        extract_mods(gpo, text_file_name)
                        
                        position = 6

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 7
                        
                        gpo.back()
                        
                        position = 8
                    except:
                        print("failed", j)
                        print(gpo.current_url)
                        print(position)
                        print(subposition)
                        gpo.back()
            except:
                print(i, "Did not find senate")
                print(gpo.current_url)
                
            #break
            gpo.back()
        #break
        gpo.back()
    #break
    gpo.back()
# Out:
# 17
# 0
# 1
# 2
# 3
# 3
# 3
# 184
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-21")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-22")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-23")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-24")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-25")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-26")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-27")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-28")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-29")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-30")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-31")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.1590206057822976-32")>, <seleniu ...
#         0
# /Users/halliday/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/halliday/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
#         20
# try close
# try close
#         21
# try close
# try close
#         22
# try close
# try close
#         23
# try close
# try close
#         24
# try close
# try close
#         25
# try close
# try close
#         26
# try close
# try close
#         27
# try close
# try close
#         28
# try close
# try close
#         29
# try close
# try close
#         30
# try close
# try close
#         31
# try close
# try close
#         32
# try close
# try close
#         33
# try close
# try close
#         34
# try close
# try close
#         35
# try close
# try close
#         36
# try close
# try close
#         37
# try close
# try close
#         38
# try close
# try close
#         39
# try close
# try close
#         40
# try close
# try close
#         41
# try close
# try close
#         42
# try close
# try close
#         43
# try close
# try close
#         44
# try close
# try close
#         45
# try close
# try close
#         46
# try close
# try close
#         47
# try close
# try close
#         48
# try close
# try close
#         49
# try close
# try close
#         50
# try close
# try close
#         51
# try close
# try close
#         52
# try close
# try close
#         53
# try close
# try close
#         54
# try close
# try close
#         55
# try close
# try close
#         56
# try close
# try close
#         57
# try close
# try close
#         58
# try close
# try close
#         59
# try close
# try close
#         60
# try close
# try close
#         61
# try close
# try close
#         62
# try close
# try close
#         63
# try close
# try close
#         64
# try close
# try close
#         65
# try close
# try close
#         66
# try close
# try close
#         67
# try close
# try close
#         68
# try close
# try close
#         69
# try close
# try close
#         70
# try close
# try close
#         71
# try close
# try close
#         72
# try close
# try close
#         73
# try close
# try close
#         74
# try close
# try close
#         75
# try close
# try close
#         76
# try close
# try close
#         77
# try close
# try close
#         78
# try close
# try close
#         79
# try close
# try close
#         80
# try close
# try close
#         81
# try close
# try close
#         82
# try close
# try close
#         83
# try close
# try close
#         84
# try close
# try close
#         85
# try close
# try close
#         86
# try close
# try close
#         87
# try close
# try close
#         88
# try close
# try close
#         89
# try close
# try close
#         90
# try close
# try close
#         91
# try close
# try close
#         92
# try close
# try close
#         93
# try close
# try close
#         94
# try close
# try close
#         95
# try close
# try close
#         96
# try close
# try close
#         97
# try close
# try close
#         98
# try close
# try close
#         99
# try close
# try close
#         100
# try close
# try close
#         101
# try close
# try close
#         102
# try close
# try close
#         103
# try close
# try close
#         104
# try close
# try close
#         105
# try close
# try close
#         106
# try close
# try close
#         107
# try close
# try close
#         108
# try close
# try close
#         109
# try close
# try close
#         110
# try close
# try close
#         111
# try close
# try close
#         112
# try close
# try close
#         113
# try close
# try close
#         114
# try close
# try close
#         115
# try close
# try close
#         116
# try close
# try close
#         117
# try close
# try close
#         118
# try close
# try close
#         119
# try close
# try close
#         120
# try close
# try close
#         121
# try close
# try close
#         122
# try close
# try close
#         123
# try close
# try close
#         124
# try close
# try close
#         125
# try close
# try close
#         126
# try close
# try close
#         127
# try close
# try close
#         128
# try close
# try close
#         129
# try close
# try close
#         130
# try close
# try close
#         131
# try close
# try close
#         132
# try close
# try close
#         133
# try close
# try close
#         134
# try close
# try close
#         135
# try close
# try close
#         136
# try close
# try close
#         137
# try close
# try close
#         138
# try close
# try close
#         139
# try close
# try close
#         140
# try close
# try close
#         141
# try close
# try close
#         142
# try close
# try close
#         143
# try close
# try close
#         144
# try close
# try close
#         145
# try close
# try close
#         146
# try close
# try close
#         147
# try close
# try close
#         148
# try close
# try close
#         149
# try close
# try close
#         150
# try close
# try close
#         151
# try close
# try close
#         152
# try close
# try close
#         153
# try close
# try close
#         154
# try close
# try close
#         155
# try close
# try close
#         156
# try close
# try close
#         157
# try close
# try close
#         158
# try close
# try close
#         159
# try close
# try close
#         160
# try close
# try close
#         161
# try close
# try close
#         162
# try close
# try close
#         163
# try close
# try close
#         164
# try close
# try close
#         165
# try close
# try close
#         166
# try close
# try close
#         167
# try close
# try close
#         168
# try close
# try close
#         169
# try close
# try close
#         170
# try close
# try close
#         171
# try close
# try close
#         172
# try close
# try close
#         173
# try close
# try close
#         174
# try close
# try close
#         175
# try close
# try close
#         176
# try close
# try close
#         177
# try close
# try close
#         178
# try close
# try close
#         179
# try close
# try close
#         180
# try close
# try close
#         181
# try close
# try close
#         182
# try close
# try close
#         183
# try close
# try close
# 3
# 3 Did not find senate
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F04%2F04-06%5C%2F5%2FHOUSE&isCollapsed=false&leafLevelBrowse=false&isDocumentResults=true&ycord=0
# 4
# 4
# 4
# 183 Did not find house
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F04%2F04-07%5C%2F6&isCollapsed=false&leafLevelBrowse=false&ycord=0
# 4
# 45
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-21")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-22")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-23")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-24")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-25")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-26")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-27")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-28")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-29")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-30")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-31")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.9352016207558367-32")>, <seleniu ...
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 5
# 5
# 5
# 22
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-21")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-22")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.6025706292573221-23")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
#         20
# try close
# try close
#         21
# try close
# try close
# 5
# 5 Did not find senate
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F04%2F04-08%5C%2F7%2FHOUSE&isCollapsed=false&leafLevelBrowse=false&isDocumentResults=true&ycord=0
# 6
# 6
# 6
# 21 Did not find house
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F04%2F04-10%5C%2F2&isCollapsed=false&leafLevelBrowse=false&ycord=0
# 6
# 3
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.26876394777344736-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.26876394777344736-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.26876394777344736-4")>]
# try close
# try close
# try close
# try close
# try close
# try close
# 7
# 7
# 7
# 20
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5086076029071693-21")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
# 7
# 7 Did not find senate
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F04%2F04-12%5C%2F4%2FHOUSE&isCollapsed=false&leafLevelBrowse=false&isDocumentResults=true&ycord=0
# 8
# 8
# 8
# 19 Did not find house
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F04%2F04-13%5C%2F5&isCollapsed=false&leafLevelBrowse=false&ycord=0
# 8
# 3
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.20551696314345635-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.20551696314345635-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.20551696314345635-4")>]
# try close
# try close
# try close
# try close
# try close
# try close
# 9
# 9
# 9
# 20
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.16641398189144052-21")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
# 9
# 9 Did not find senate
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F04%2F04-14%5C%2F6%2FHOUSE&isCollapsed=false&leafLevelBrowse=false&isDocumentResults=true&ycord=0
# 10
# 10
# 10
# 14
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4440724130887699-15")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
# 10
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.28294241168645073-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.28294241168645073-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.28294241168645073-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.28294241168645073-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 11
# 11
# 11
# 19
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.5395015649841883-20")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
# 11
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.13882401078447248-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.13882401078447248-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.13882401078447248-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.13882401078447248-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 12
# 12
# 12
# 13
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.42303761824300135-14")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
# 12
# 54
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-21")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-22")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-23")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-24")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-25")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-26")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-27")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-28")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-29")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-30")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-31")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.4888541925364227-32")>, <seleniu ...
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 13
# 13
# 13
# 99
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-21")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-22")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-23")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-24")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-25")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-26")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-27")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-28")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-29")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-30")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-31")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.7026778361461135-32")>, <seleniu ...
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
#         20
# try close
# try close
#         21
# try close
# try close
#         22
# try close
# try close
#         23
# try close
# try close
#         24
# try close
# try close
#         25
# try close
# try close
#         26
# try close
# try close
#         27
# try close
# try close
#         28
# try close
# try close
#         29
# try close
# try close
#         30
# try close
# try close
#         31
# try close
# try close
#         32
# try close
# try close
#         33
# try close
# try close
#         34
# try close
# try close
#         35
# try close
# try close
#         36
# try close
# try close
#         37
# try close
# try close
#         38
# try close
# try close
#         39
# try close
# try close
#         40
# try close
# try close
#         41
# try close
# try close
#         42
# try close
# try close
#         43
# try close
# try close
#         44
# try close
# try close
#         45
# try close
# try close
#         46
# try close
# try close
#         47
# try close
# try close
#         48
# try close
# try close
#         49
# try close
# try close
#         50
# try close
# try close
#         51
# try close
# try close
#         52
# try close
# try close
#         53
# try close
# try close
#         54
# try close
# try close
#         55
# try close
# try close
#         56
# try close
# try close
#         57
# try close
# try close
#         58
# try close
# try close
#         59
# try close
# try close
#         60
# try close
# try close
#         61
# try close
# try close
#         62
# try close
# try close
#         63
# try close
# try close
#         64
# try close
# try close
#         65
# try close
# try close
#         66
# try close
# try close
#         67
# try close
# try close
#         68
# try close
# try close
#         69
# try close
# try close
#         70
# try close
# try close
#         71
# try close
# try close
#         72
# try close
# try close
#         73
# try close
# try close
#         74
# try close
# try close
#         75
# try close
# try close
#         76
# try close
# try close
#         77
# try close
# try close
#         78
# try close
# try close
#         79
# try close
# try close
#         80
# try close
# try close
#         81
# try close
# try close
#         82
# try close
# try close
#         83
# try close
# try close
#         84
# try close
# try close
#         85
# try close
# try close
#         86
# try close
# try close
#         87
# try close
# try close
#         88
# try close
# try close
#         89
# ...
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 2
# 2
# 2
# 71 Did not find house
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F08%2F08-03%5C%2F5&isCollapsed=false&leafLevelBrowse=false&ycord=546
# 2
# 106
# [<selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-2")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-3")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-4")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-5")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-6")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-7")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-8")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-9")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-10")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-11")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-12")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-13")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-14")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-15")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-16")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-17")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-18")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-19")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-20")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-21")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-22")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-23")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-24")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-25")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-26")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-27")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-28")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-29")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-30")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-31")>, <selenium.webdriver.remote.webelement.WebElement (session="0c54881556b19cc8ae8c46c1bf00a4f2", element="0.2061452354881963-32")>, <seleniu ...
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# except close
# failed 23
# 2 Did not find senate
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-11-ca4f843facdd> in extract_text(gpo)
#       5         gpo.switch_to_window(handles[1])
# ----> 6         extracted_stuff = extract_text_from_url(gpo.current_url)
#       7
#
# <ipython-input-15-fdfaf7cf3a02> in extract_text_from_url(url)
#       1 def extract_text_from_url(url):
# ----> 2     stuff = requests.get(url)
#       3     stuff_parsed = BeautifulSoup(stuff.content, "html")
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     493         )
# --> 494         prep = self.prepare_request(req)
#     495
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in prepare_request(self, request)
#     436             cookies=merged_cookies,
# --> 437             hooks=merge_hooks(request.hooks, self.hooks),
#     438         )
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     304         self.prepare_method(method)
# --> 305         self.prepare_url(url, params)
#     306         self.prepare_headers(headers)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in prepare_url(self, url, params)
#     378
# --> 379             raise MissingSchema(error)
#     380
#
# MissingSchema: Invalid URL 'None': No schema supplied. Perhaps you meant http://None?
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-16-2ed0078488f9> in <module>()
#     132                         #changing default window & save file, return name
# --> 133                         text_file_name = extract_text(gpo)
#     134
#
# <ipython-input-11-ca4f843facdd> in extract_text(gpo)
#      17         print("except close")
# ---> 18         gpo.close()
#      19
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     678         """
# --> 679         self.execute(Command.CLOSE)
#     680
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.3 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-16-2ed0078488f9> in <module>()
#     158                         print("failed", j)
# --> 159                         print(gpo.current_url)
#     160                         print(position)
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in current_url(self)
#     659         """
# --> 660         return self.execute(Command.GET_CURRENT_URL)['value']
#     661
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.3 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-16-2ed0078488f9> in <module>()
#     163             except:
#     164                 print(i, "Did not find senate")
# --> 165                 print(gpo.current_url)
#     166
#     167             #break
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in current_url(self)
#     658             driver.current_url
#     659         """
# --> 660         return self.execute(Command.GET_CURRENT_URL)['value']
#     661
#     662     @property
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.3 x86_64)
