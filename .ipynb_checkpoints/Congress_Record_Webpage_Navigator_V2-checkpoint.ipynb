# %%
import pandas
import urllib
from selenium import webdriver
import numpy as np
from time import sleep
import requests
from bs4 import BeautifulSoup
import re

# %%
gpo=webdriver.Chrome()
gpo.get('https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC')

# %%
def extract_text(gpo):
    try:
        handles = list(gpo.window_handles)
        assert len(handles) > 1
        gpo.switch_to_window(handles[1])
        extracted_stuff = extract_text_from_url(gpo.current_url)

        ## create a file in local repository
        file_name = create_text_file_name(gpo.current_url)
        file = open(file_name,'w')
        file.write(extracted_stuff)
        file.close()
        print("try close")
        gpo.close()
        return file_name
    except:
        print("except close")
        gpo.close()

# %%
def extract_mods(gpo, txt_file_name):
    try:
        handles = list(gpo.window_handles)
        assert len(handles) > 1
        gpo.switch_to_window(handles[1])

        mods_url = gpo.current_url
        sleep(1)
        extracted_stuff = extract_mods_from_url(mods_url)

        ## create a file in local repository
        file_name = txt_file_name[0:-3] + 'xml'
        file = open(file_name, 'w')
        file.write(extracted_stuff)
        file.close()
        print("try close")
        gpo.close()
    except:
        print("except close")
        gpo.close()

# %%
def create_text_file_name(url):
    pattern = '(?<=html/).*'
    name = re.findall(pattern, url)
    return name[0][:-3] + 'txt'

# %%
def extract_mods_from_url(url):
    stuff = requests.get(url)
    stuff_parsed = BeautifulSoup(stuff.content, 'xml')
    return str(stuff_parsed.find_all('mods')[0])

# %%
def extract_text_from_url(url):
    stuff = requests.get(url)
    stuff_parsed = BeautifulSoup(stuff.content, "html")
    return stuff_parsed.get_text()

# %%
april = 7
DAY = 2
year = gpo.find_elements_by_xpath(".//div[@class='level1 browse-level']/a")
for i in np.arange(len(year)):
    if i == 0:
        continue
    if i == 2:
        break
    time_y = i
    year = gpo.find_elements_by_xpath(".//div[@class='level1 browse-level']/a")
    x = year[i].click()
    month = gpo.find_elements_by_xpath(".//div[@class='level2 browse-level']/a")
    for i in np.arange(len(month)):
        if april != 0:
            april -= 1
            continue
        time_m = i
        month = gpo.find_elements_by_xpath(".//div[@class='level2 browse-level']/a")
        month[i].click()
        day = gpo.find_elements_by_xpath(".//div[@class='level3 browse-level']/a")
        print(len(day))
        for i in np.arange(len(day)):
            print(i)
            if DAY != 0:
                DAY -= 1
                continue
            time_d = i
            day = gpo.find_elements_by_xpath(".//div[@class='level3 browse-level']/a")
            print(i)
            day[i].click()
            try: 
                print(i)
                house = gpo.find_element_by_partial_link_text('House')
                house.click()
                house_more = gpo.find_elements_by_partial_link_text('More')
                house_more = house_more[1:]
                print(len(house_more))
                print(house_more)
                for j in np.arange(len(house_more)):
                    position = 1
                    subposition = 1
                    try:
                        print("       ", j)
                        house_more = gpo.find_elements_by_partial_link_text('More')
                        subposition = 2
                        house_more = house_more[1:]
                        subposition = 3
                        
                        position = 2

                        house_more[j].click()
                        subposition = 2
                        house_text = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[1]/td[2]/a[1]')
                        subposition = 3
                        house_mods = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[2]/td[2]/a')
                        subposition = 4
                        default_handle = gpo.current_window_handle
                        subposition = 5
                        house_text.click()
                        subposition = 6
                        
                        position = 3

                        #changing default window & save file, return name
                        text_file_name = extract_text(gpo)
                        
                        position = 4

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 5

                        #go to mods page & save file
                        house_mods.click()
                        subposition = 2
                        extract_mods(gpo, text_file_name)
                        
                        position = 6

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 7
                        
                        gpo.back()
                        
                        position = 8
                        
                    except:
                        print("failed", j)
                        print(gpo.current_url)
                        print(position)
                        print(subposition)
                        gpo.back()
            except:
                print(i, "Did not find house")
                print(gpo.current_url)
            
            try:
                print(i)
                senate = gpo.find_element_by_partial_link_text('Senate')
                senate.click()
                senate_more = gpo.find_elements_by_partial_link_text('More')
                senate_more = senate_more[1:]
                print(len(senate_more))
                print(senate_more)
                for j in np.arange(len(senate_more)):
                    position = 1
                    subposition = 1
                    try:
                        senate_more = gpo.find_elements_by_partial_link_text('More')
                        subposition = 2
                        senate_more = senate_more[1:]
                        subposition = 3
                        
                        position = 2

                        senate_more[j].click()
                        subposition = 2
                        senate_text = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[1]/td[2]/a[1]')
                        subposition = 3
                        senate_mods = gpo.find_element_by_xpath('.//tr/td[3]/div/table[1]/tbody/tr[2]/td[2]/a')
                        subposition = 4
                        default_handle = gpo.current_window_handle
                        subposition = 5
                        senate_text.click()
                        subposition = 6
                        
                        position = 3

                        #changing default window & save file, return name
                        text_file_name = extract_text(gpo)
                        
                        position = 4

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 5

                        #go to mods page & save file
                        senate_mods.click()
                        subposition = 2
                        extract_mods(gpo, text_file_name)
                        
                        position = 6

                        #return to main window
                        gpo.switch_to_window(default_handle)
                        
                        position = 7
                        
                        gpo.back()
                        
                        position = 8
                    except:
                        print("failed", j)
                        print(gpo.current_url)
                        print(position)
                        print(subposition)
                        gpo.back()
            except:
                print(i, "Did not find senate")
                print(gpo.current_url)
                
            #break
            gpo.back()
        #break
        gpo.back()
    #break
    gpo.back()
# Out:
# 11
# 0
# 1
# 2
# 2
# 2
# 2 Did not find house
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F08%2F08-03%5C%2F5&isCollapsed=false&leafLevelBrowse=false&ycord=0
# 2
# 106
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-18")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-19")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-20")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-21")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-22")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-23")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-24")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-25")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-26")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-27")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-28")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-29")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-30")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-31")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4813208818213095-32")>, <seleniu ...
# /Users/halliday/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/halliday/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 3
# 3
# 3
# 31
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-18")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-19")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-20")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-21")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-22")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-23")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-24")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-25")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-26")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-27")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-28")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-29")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-30")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25576453952003564-31")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.25 ...
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
#         20
# try close
# try close
#         21
# try close
# try close
#         22
# try close
# try close
#         23
# try close
# try close
#         24
# try close
# try close
#         25
# try close
# try close
#         26
# try close
# try close
#         27
# try close
# try close
#         28
# try close
# try close
#         29
# try close
# try close
#         30
# try close
# try close
# 3
# 3
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9641622946018067-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9641622946018067-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9641622946018067-4")>]
# try close
# try close
# try close
# try close
# try close
# try close
# 4
# 4
# 4
# 18
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-18")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9617980462559668-19")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
# 4
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4924311525450631-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4924311525450631-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4924311525450631-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4924311525450631-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 5
# 5
# 5
# 21
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-18")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-19")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-20")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-21")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.3279068989438616-22")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# failed 13
# https://www.gpo.gov/fdsys/search/pagedetails.action?collectionCode=CREC&browsePath=2017%2F08%2F08-11%5C%2F6%2FHOUSE&granuleId=CREC-2017-08-11-pt1-PgH6603-2&packageId=CREC-2017-08-11&fromBrowse=true
# 2
# 2
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
#         20
# try close
# try close
# 5
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.07101514648485163-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.07101514648485163-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.07101514648485163-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.07101514648485163-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 6
# 6
# 6
# 17
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7561553243569121-18")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
# 6
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4444283470819941-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4444283470819941-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4444283470819941-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.4444283470819941-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 7
# 7
# 7
# 22
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-18")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-19")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-20")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-21")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-22")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9043899330065706-23")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
#         20
# try close
# try close
#         21
# try close
# try close
# 7
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7754444993129332-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7754444993129332-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7754444993129332-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7754444993129332-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 8
# 8
# 8
# 14
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04590319562354672-15")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
# 8
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7716239730576353-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7716239730576353-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7716239730576353-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7716239730576353-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 9
# 9
# 9
# 15
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.6726253663150537-16")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
# 9
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.747708263652926-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.747708263652926-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.747708263652926-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.747708263652926-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 10
# 10
# 10
# 14
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.697693343074536-15")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
# 10
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.40835253346261435-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.40835253346261435-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.40835253346261435-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.40835253346261435-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 16
# 0
# 0
# 0
# 16
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.0984839815599734-17")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
# 0
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9470336119791882-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9470336119791882-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9470336119791882-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.9470336119791882-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 1
# 1
# 1
# 62
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-18")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-19")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-20")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-21")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-22")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-23")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-24")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-25")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-26")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-27")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-28")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-29")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-30")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-31")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2572125878824103-32")>, <seleniu ...
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
#         14
# try close
# try close
#         15
# try close
# try close
#         16
# try close
# try close
#         17
# try close
# try close
#         18
# try close
# try close
#         19
# try close
# try close
#         20
# try close
# try close
#         21
# try close
# try close
#         22
# try close
# try close
#         23
# try close
# try close
#         24
# try close
# try close
#         25
# try close
# try close
#         26
# try close
# try close
#         27
# try close
# try close
#         28
# try close
# try close
#         29
# try close
# try close
#         30
# try close
# try close
#         31
# try close
# try close
#         32
# try close
# try close
#         33
# try close
# try close
#         34
# try close
# try close
#         35
# try close
# try close
#         36
# try close
# try close
#         37
# try close
# try close
#         38
# try close
# try close
#         39
# try close
# try close
#         40
# try close
# try close
#         41
# try close
# try close
#         42
# try close
# try close
#         43
# try close
# try close
#         44
# try close
# try close
#         45
# try close
# try close
#         46
# try close
# try close
#         47
# try close
# try close
#         48
# try close
# try close
#         49
# try close
# try close
#         50
# try close
# try close
#         51
# try close
# try close
#         52
# try close
# try close
#         53
# try close
# try close
#         54
# try close
# try close
#         55
# try close
# try close
#         56
# try close
# try close
#         57
# try close
# try close
#         58
# try close
# try close
#         59
# try close
# try close
#         60
# try close
# try close
#         61
# try close
# try close
# 1
# 50
# ...
#         62
# try close
# try close
#         63
# try close
# try close
#         64
# try close
# try close
#         65
# try close
# try close
#         66
# try close
# try close
#         67
# try close
# try close
#         68
# try close
# try close
#         69
# try close
# try close
#         70
# try close
# try close
#         71
# try close
# try close
#         72
# try close
# try close
#         73
# try close
# try close
#         74
# try close
# try close
#         75
# try close
# try close
#         76
# try close
# try close
#         77
# try close
# try close
#         78
# try close
# try close
#         79
# try close
# try close
#         80
# try close
# try close
#         81
# try close
# try close
#         82
# try close
# try close
#         83
# try close
# try close
#         84
# try close
# try close
# 13
# 142
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-15")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-16")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-17")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-18")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-19")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-20")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-21")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-22")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-23")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-24")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-25")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-26")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-27")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-28")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-29")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-30")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-31")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.508255602018095-32")>, <selenium.webdriver.remote.webelement.W ...
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# except close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# failed 88
# https://www.gpo.gov/fdsys/search/pagedetails.action?collectionCode=CREC&browsePath=2017%2F12%2F12-21%5C%2F5%2FSENATE&granuleId=CREC-2017-12-21-pt1-PgS8253-3&packageId=CREC-2017-12-21&fromBrowse=true
# 2
# 2
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# except close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# 14
# 14
# 14
# 14
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-14")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.04147495616744079-15")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
#         13
# try close
# try close
# 14
# 14 Did not find senate
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F12%2F12-22%5C%2F6%2FHOUSE&isCollapsed=false&leafLevelBrowse=false&isDocumentResults=true&ycord=740
# 15
# 15
# 15
# 15 Did not find house
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F12%2F12-23%5C%2F7&isCollapsed=false&leafLevelBrowse=false&ycord=740
# 15
# 3
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.925729297088165-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.925729297088165-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.925729297088165-4")>]
# try close
# try close
# try close
# try close
# try close
# try close
# 16
# 16
# 16
# 13
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-11")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-12")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-13")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.2552114327274926-14")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
#         10
# try close
# try close
#         11
# try close
# try close
#         12
# try close
# try close
# 16
# 16 Did not find senate
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F12%2F12-26%5C%2F3%2FHOUSE&isCollapsed=false&leafLevelBrowse=false&isDocumentResults=true&ycord=720
# 17
# 17
# 17
# 17 Did not find house
# https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=CREC&browsePath=2017%2F12%2F12-27%5C%2F4&isCollapsed=false&leafLevelBrowse=false&ycord=720
# 17
# 3
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.38902059404051803-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.38902059404051803-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.38902059404051803-4")>]
# try close
# try close
# try close
# try close
# try close
# try close
# 18
# 18
# 18
# 10
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-5")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-6")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-7")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-8")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-9")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-10")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.7397812469182747-11")>]
#         0
# try close
# try close
#         1
# try close
# try close
#         2
# try close
# try close
#         3
# try close
# try close
#         4
# try close
# try close
#         5
# try close
# try close
#         6
# try close
# try close
#         7
# try close
# try close
#         8
# try close
# try close
#         9
# try close
# try close
# 18
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.025618597571442914-2")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.025618597571442914-3")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.025618597571442914-4")>, <selenium.webdriver.remote.webelement.WebElement (session="8f46afd9a46ca472f4c76e3351af61cd", element="0.025618597571442914-5")>]
# try close
# try close
# try close
# try close
# try close
# try close
# try close
# try close
